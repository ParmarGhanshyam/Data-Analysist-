# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('/content/data.csv')
data
# Out:
#      Customer       State  ...  Vehicle Class Vehicle Size
# 0     BU79786  Washington  ...   Two-Door Car      Medsize
# 1     QZ44356     Arizona  ...  Four-Door Car      Medsize
# 2     AI49188      Nevada  ...   Two-Door Car      Medsize
# 3     WW63253  California  ...            SUV      Medsize
# 4     HB64268  Washington  ...  Four-Door Car      Medsize
# ...       ...         ...  ...            ...          ...
# 9129  LA72316  California  ...  Four-Door Car      Medsize
# 9130  PK87824  California  ...  Four-Door Car      Medsize
# 9131  TD14365  California  ...  Four-Door Car      Medsize
# 9132  UP19263  California  ...  Four-Door Car        Large
# 9133  Y167826  California  ...   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
data.shape
# Out:
# (9134, 24)

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
# importing the required library

import seaborn as sns
import matplotlib.pyplot as plt

# read a tips.csv file from seaborn library
df = data

# count plot along y axis
sns.countplot(x ='State', hue = "Gender", data = df)
plt.xlabel("Male and Female Count")
plt.ylabel("states")
plt.title("Analysis male and female base on states")
# Show the plot
plt.show()

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
# checking married status people 
import seaborn as sns
import matplotlib.pyplot as plt
df = data
sns.countplot(x = 'Marital Status',data = df,color="salmon")
plt.title("Analysis Marital Status")
plt.show()

# %%
sns.catplot(x="Gender",y="Marital Status",data=data)

# %%
sns.set_context('paper')
# load dataset
titanic = data
# create plot
sns.countplot(x = 'Marital Status', hue = 'Gender', data = titanic, palette = 'magma')
plt.title('Analysis Male&female Count On Martial status')
plt.show()

# %%
sns.set_context('paper')
 
# load dataset
titanic = data
# create plot
sns.countplot(x = 'State', hue = 'Education', data = titanic, palette = 'magma')
plt.title('Analysis States base on Education')
plt.show()

# %%
sns.set_context('paper')
 
# load dataset
titanic = data
# create plot
sns.countplot(x = 'Location Code', hue = 'Vehicle Size', data = titanic, palette = 'magma')
plt.title('Analysis location code base on Vehicle Size')
plt.show()

# %%
sns.set_context('paper')
 
# load dataset
titanic = data
# create plot
sns.countplot(x = 'State', hue = 'Vehicle Size', data = titanic, palette = 'magma')
plt.title('Analysis state base on Vechicle size')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = data
sns.countplot(x = 'EmploymentStatus',data = df,color="salmon")
plt.title("EmploymentStatus counts")
plt.show()

# %%
sns.set_context('paper')
titanic = data
# create plot
sns.countplot(x = 'EmploymentStatus', hue = 'State', data = titanic, palette = 'magma')
plt.title('Analysis Employment Status based on States')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = data
sns.countplot(x = 'Policy',data = df,color="red")  
plt.xticks(rotation=45)
plt.title("Analysis Total Policy Analysis")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = data
sns.countplot(x = 'Policy Type',data = df,color="red")  
plt.xticks(rotation=45)
plt.title("Analysis types of Policy")
plt.show()

# %%
sns.set_context('paper')
data = data
sns.countplot(x = 'EmploymentStatus', hue = 'Location Code', data = data, palette = 'magma')
plt.title('Analysis Employment base on Location code')
plt.show()

# %%
sns.set_context('paper')
data = data
sns.countplot(x = 'Marital Status', hue = 'Location Code', data = data, palette = 'magma')
plt.title('Analysis Employment base on Location code')
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

g = sns.catplot(
    data=data, kind="bar",
    x="EmploymentStatus", y="Income", hue="State",
    ci="sd", palette="dark", alpha=.6, height=6
).set(title='visualize two coloum comparision')
g.set_xticklabels(rotation=30)
plt.xticks(rotation=45)
g.despine(left=True)
g.set_axis_labels("EmploymentStatus", "Income Price")
g.legend.set_title("")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
from matplotlib.pyplot import figure

g = sns.catplot(
    data=data, kind="bar",
    x="Policy", y="Monthly Premium Auto", hue="Gender",
    ci="sd", palette="dark", alpha=.6, height=6
).set(title='visualize two coloum comparision')
g.set_xticklabels(rotation=30)
plt.xticks(rotation=45)
g.despine(left=True)
g.set_axis_labels("Policy Type", "Monthly Premium")
g.legend.set_title("")

# %%
sns.set_style("ticks")
sns.pairplot(data,hue = 'Gender',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %%
data.groupby(["Gender"]).count()
# Out:
#         Customer  State  ...  Vehicle Class  Vehicle Size
# Gender                   ...
# F           4658   4658  ...           4658          4658
# M           4476   4476  ...           4476          4476
#
# [2 rows x 23 columns]

# %%
sns.set_context('paper')
data = data
sns.countplot(x = 'Marital Status', hue = 'Vehicle Class', data = data, palette = 'magma')
plt.title('Analysis Employment base on Location code')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = data
sns.countplot(x = 'Gender',data = df,color="purple")
plt.title("Analysis Marital Status")
plt.show()

# %%
x = data['Monthly Premium Auto']
y = data['Number of Policies']
plt.figure(figsize=(14,6))
sns.set(rc={'axes.facecolor':'cornflowerblue',"axes.grid":True,'xtick.labelsize':14,'ytick.labelsize':14})
sns.lineplot(x=x,y=y,data=data , linewidth = 2.5)

plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=x,y=y,hue='Gender',data=data)
plt.show()

# %%
data.hist(bins=40 , figsize=(20,20)) #Pandas Hist function
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/data.csv')
data.head()
# Out:
#   Customer       State  ...  Vehicle Class Vehicle Size
# 0  BU79786  Washington  ...   Two-Door Car      Medsize
# 1  QZ44356     Arizona  ...  Four-Door Car      Medsize
# 2  AI49188      Nevada  ...   Two-Door Car      Medsize
# 3  WW63253  California  ...            SUV      Medsize
# 4  HB64268  Washington  ...  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
options = ['Employed', 'Unemployed']
rslt_df = data[data['EmploymentStatus'].isin(options)]
rslt_df['EmploymentStatus'].unique()
len(rslt_df['EmploymentStatus'])
# Out:
# 8015

# %%
y = data['EmploymentStatus']

# %%
len(y)
# Out:
# 9134

# %%
x = data.iloc[:,:-1]

# %%
x = np.array(X)
y = np.array(y)

# %%
y

# %% [markdown]
# **Model training**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(X_train,y_train)

# %%
dataset  = pd.read_csv('/content/data.csv')
dataset.head()
# Out:
#   Customer       State  ...  Vehicle Class Vehicle Size
# 0  BU79786  Washington  ...   Two-Door Car      Medsize
# 1  QZ44356     Arizona  ...  Four-Door Car      Medsize
# 2  AI49188      Nevada  ...   Two-Door Car      Medsize
# 3  WW63253  California  ...            SUV      Medsize
# 4  HB64268  Washington  ...  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
X = dataset['Vehicle Size']

# %%
X
# Out:
# 0       Medsize
# 1       Medsize
# 2       Medsize
# 3       Medsize
# 4       Medsize
#          ...
# 9129    Medsize
# 9130    Medsize
# 9131    Medsize
# 9132      Large
# 9133    Medsize
# Name: Vehicle Size, Length: 9134, dtype: object

# %%
vechicle_size = pd.get_dummies(X,drop_first = True)

# %%
vechicle_size
# Out:
#       Medsize  Small
# 0           1      0
# 1           1      0
# 2           1      0
# 3           1      0
# 4           1      0
# ...       ...    ...
# 9129        1      0
# 9130        1      0
# 9131        1      0
# 9132        0      0
# 9133        1      0
#
# [9134 rows x 2 columns]

# %%
X = pd.concat([X,vechicle_size],axis=1)

# %%
X
# Out:
#      Vehicle Size  Medsize  Small
# 0         Medsize        1      0
# 1         Medsize        1      0
# 2         Medsize        1      0
# 3         Medsize        1      0
# 4         Medsize        1      0
# ...           ...      ...    ...
# 9129      Medsize        1      0
# 9130      Medsize        1      0
# 9131      Medsize        1      0
# 9132        Large        0      0
# 9133      Medsize        1      0
#
# [9134 rows x 3 columns]

# %%
X = X.drop(['Vehicle Size'], axis = 1)

# %%
X
# Out:
#       Medsize  Small
# 0           1      0
# 1           1      0
# 2           1      0
# 3           1      0
# 4           1      0
# ...       ...    ...
# 9129        1      0
# 9130        1      0
# 9131        1      0
# 9132        0      0
# 9133        1      0
#
# [9134 rows x 2 columns]

# %%
y = dataset.iloc[:,7:8]

# %%
y
# Out:
#      EmploymentStatus
# 0            Employed
# 1          Unemployed
# 2            Employed
# 3          Unemployed
# 4            Employed
# ...               ...
# 9129         Employed
# 9130         Employed
# 9131       Unemployed
# 9132         Employed
# 9133       Unemployed
#
# [9134 rows x 1 columns]

# %%
y1 = pd.get_dummies(dataset, columns=['EmploymentStatus'],drop_first=True, prefix=['EmploymentStatus'])

# %%
y1
# Out:
#      Customer  ... EmploymentStatus_Unemployed
# 0     BU79786  ...                           0
# 1     QZ44356  ...                           1
# 2     AI49188  ...                           0
# 3     WW63253  ...                           1
# 4     HB64268  ...                           0
# ...       ...  ...                         ...
# 9129  LA72316  ...                           0
# 9130  PK87824  ...                           0
# 9131  TD14365  ...                           1
# 9132  UP19263  ...                           0
# 9133  Y167826  ...                           1
#
# [9134 rows x 27 columns]

# %%
y1 = y1.drop(['EmploymentStatus_Medical Leave','EmploymentStatus_Retired'], axis = 1)

# %%
y1
# Out:
#      Customer  ... EmploymentStatus_Unemployed
# 0     BU79786  ...                           0
# 1     QZ44356  ...                           1
# 2     AI49188  ...                           0
# 3     WW63253  ...                           1
# 4     HB64268  ...                           0
# ...       ...  ...                         ...
# 9129  LA72316  ...                           0
# 9130  PK87824  ...                           0
# 9131  TD14365  ...                           1
# 9132  UP19263  ...                           0
# 9133  Y167826  ...                           1
#
# [9134 rows x 25 columns]

# %%
y1 = y1.iloc[:,23:25]

# %%
y1
# Out:
#       EmploymentStatus_Employed  EmploymentStatus_Unemployed
# 0                             1                            0
# 1                             0                            1
# 2                             1                            0
# 3                             0                            1
# 4                             1                            0
# ...                         ...                          ...
# 9129                          1                            0
# 9130                          1                            0
# 9131                          0                            1
# 9132                          1                            0
# 9133                          0                            1
#
# [9134 rows x 2 columns]

# %%
X
# Out:
#       Medsize  Small
# 0           1      0
# 1           1      0
# 2           1      0
# 3           1      0
# 4           1      0
# ...       ...    ...
# 9129        1      0
# 9130        1      0
# 9131        1      0
# 9132        0      0
# 9133        1      0
#
# [9134 rows x 2 columns]

# %%
y1
# Out:
#       EmploymentStatus_Employed  EmploymentStatus_Unemployed
# 0                             1                            0
# 1                             0                            1
# 2                             1                            0
# 3                             0                            1
# 4                             1                            0
# ...                         ...                          ...
# 9129                          1                            0
# 9130                          1                            0
# 9131                          0                            1
# 9132                          1                            0
# 9133                          0                            1
#
# [9134 rows x 2 columns]
